# %%
# pip install rake_nltk
from rake_nltk import Rake
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../Dataset/eclipse_platform.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data['Description'].isnull().sum()
data['Title'].isnull().sum()
data=data.dropna(axis=0,subset=['Description'])

dataframe = data[['Issue_id', 'Priority', 'Component', 'Description', 'Title']]
# dataframe=df.head(10)
# df.head()

# %%
# project_name='JDT'
# component_name='UI'

# %%
# selected_data = dataframe.loc[(dataframe['Product'] == project_name) & (dataframe['Component'] == component_name)]
# # selected_data=selected_data.head(10)
selected_data=dataframe

selected_data.shape
# Out:
# (85027, 5)

# %%
#!pip install gensim
from gensim.parsing.preprocessing import remove_stopwords
# Out:
# C:\Users\abdul\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# from gensim.parsing.preprocessing import remove_stopwords
# my_list = []
# summary = selected_data['Title'].values
# for  sent in selected_data.index:
#     filtered_sentence = remove_stopwords(selected_data.at[sent,'Title'])
#     selected_data.loc[sent, 'Keywords'] = filtered_sentence

# %%
selected_data.head()
# Out:
#    Issue_id Priority Component  \
# 0         1       P3      Team
# 1         2       P5      Team
# 2         3       P5      Team
# 3         4       P5      Team
# 4         5       P3      Team
#
#                                          Description  \
# 0  - Setup a project that contains a *.gif resour...
# 1  Opening repository resource always open the de...
# 2  KM (10/2/2001 5:55:18 PM); \tThis PR about the...
# 3  - become synchronized with some project in a r...
# 4  For getting/setting the managed state of a res...
#
#                                                Title
# 0    Usability issue with external editors (1GE6IRL)
# 1  Opening repository resources doesnt honor type...
# 2          Sync does not indicate deletion (1GIEN83)
# 3  need better error message if catching up over ...
# 4  ISharingManager sharing API inconsistent (1GAU...

# %%
# !pip3 install --upgrade tensorflow-gpu
# # Install TF-Hub.
# !pip3 install tensorflow-hub

# %%
import tensorflow as tf
import tensorflow_hub as hub

# %%
# model = hub.Module("universal-sentence-encoder_4")
module_url = "../../universal-sentence-encoder_4"
model = hub.load(module_url)

print ("module %s loaded" % module_url)
# Out:
# module ../../universal-sentence-encoder_4 loaded

# %%
summary = selected_data['Title'].values
description=selected_data['Description'].values

# %%
query = "[CVS UI] Need VCM Prefs - Default Repo Connection (1GC3746)"
# query_sentence = remove_stopwords(query)
# query_vec = model([query_sentence])[0]
query_vec = model([query])[0]

query2 = "It would be helpful if there was a notion of default repository connection so that when you; connected a project you wouldnt have to walk through the list everytime.; ; Not sure how this goes into prefs if its never been created before.  Maybe when you create them you can mark one; as the default.; ; At a minimum having a default repository TYPE (cvs/cc) would be helpful (which then the pulldown in the repo connection; wizard has a default).; ; NOTES:"

query_vec2 = model([query2])[0]

# %%
def cosine(u, v):
    return (np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v)))*100

# %%
for  sent in selected_data.index:
  sim = cosine(query_vec, model([selected_data.at[sent,'Title']])[0])
  selected_data.loc[sent, 'Similarity'] = sim
  sim2 = cosine(query_vec2, model([selected_data.at[sent, 'Description']])[0])
  selected_data.loc[sent, 'SimilarityDescription'] = sim2
# Out:
# C:\Users\abdul\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\abdul\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
# datanew=selected_data.loc[(selected_data['Similarity'] >= 0)]
# datanew
selected_data.head()
# Out:
#    Issue_id Priority Component  \
# 0         1       P3      Team
# 1         2       P5      Team
# 2         3       P5      Team
# 3         4       P5      Team
# 4         5       P3      Team
#
#                                          Description  \
# 0  - Setup a project that contains a *.gif resour...
# 1  Opening repository resource always open the de...
# 2  KM (10/2/2001 5:55:18 PM); \tThis PR about the...
# 3  - become synchronized with some project in a r...
# 4  For getting/setting the managed state of a res...
#
#                                                Title  Similarity  \
# 0    Usability issue with external editors (1GE6IRL)   18.763900
# 1  Opening repository resources doesnt honor type...   34.989721
# 2          Sync does not indicate deletion (1GIEN83)   12.727782
# 3  need better error message if catching up over ...    6.684190
# 4  ISharingManager sharing API inconsistent (1GAU...   20.882341
#
#    SimilarityDescription
# 0              39.028534
# 1              35.697800
# 2              33.479184
# 3              33.906001
# 4              28.604478

# %%
tempData=selected_data

# %%
for sent in tempData.index:
    avgData = (tempData.at[sent,'Similarity']+tempData.at[sent,'SimilarityDescription'])/2
    tempData.loc[sent,'AvgSimilarity'] = avgData
# Out:
# C:\Users\abdul\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\abdul\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
tempData=tempData.sort_values(by='AvgSimilarity', ascending=False)
tempData.head(20)
# Out:
#        Issue_id Priority Component  \
# 24           25       P3      Team
# 11516     22171       P3      Team
# 4055       8712       P3      Team
# 25           26       P5      Team
# 63677    196475       P3       CVS
# 10814     20955       P3      Team
# 18279     34915       P3      Team
# 4158       8891       P3      Team
# 38           39       P3      Team
# 13578     26062       P2      Team
# 7138      14751       P3      Team
# 3331       7410       P3      Team
# 206         207       P3      Team
# 7148      14766       P3      Team
# 57178    157250       P3       CVS
# 4370       9279       P3      Team
# 6207      13026       P3      Team
# 2581       5782       P2      Team
# 10521     20463       P5      Team
# 34827     70962       P5       CVS
#
#                                              Description  \
# 24     It would be helpful if there was a notion of d...
# 11516  I havent found any way to create a new reposit...
# 4055   When sharing a project; its great that we now ...
# 25     Its very awkward that you cannot create a new ...
# 63677  Build ID: I20070710-1416; ; I wonder if we cou...
# 10814  Build 20020624; ; Would like to be able to nam...
# 18279  Many times; Ive made changes to files which I ...
# 4158   You cant change any of the properties of a CVS...
# 38     I may have logged this previously.; ; It would...
# 13578  When i have an entry in the .cvsignore file th...
# 7138   Build 20020425; ; In the repository properties...
# 3331   When creating a new repo connection; if you on...
# 206    - create a new repository connection; - select...
# 7148   The easiest way to see the problem is to expan...
# 57178  Actually; it is possible to paste a CVS connec...
# 4370   When creating a new repo location; the validat...
# 6207   If I have a project checked out from CVS by a ...
# 2581   At some point in the past (before I used Eclip...
# 10521  CVS default setting for empty directories; ins...
# 34827  Using first 3.1 integration build I20040727102...
#
#                                                    Title  Similarity  \
# 24     [CVS UI] Need VCM Prefs - Default Repo Connect...  100.000000
# 11516  [CVS UI] New Repo Location wizard should be ac...   63.709462
# 4055   Share with CVS wizard: repo connection list di...   54.821086
# 25     Need to be able to create a new Repo Connectio...   49.207249
# 63677  [Repo View] Ordering in the CVS Repositories view   53.190613
# 10814   [CVS UI] Would like to name repository locations   61.612791
# 18279  Load latest from repo option in sync view outg...   52.147835
# 4158   Cant change properties of a CVS connection in ...   60.472786
# 38      Preference for repo type would be nice (1GCPKVS)   44.037658
# 13578  [CVS UI] add to version control and .cvsignore...   53.607720
# 7138        [CVS UI] Cant edit all repository properties   58.996427
# 3331    Should skip repo type selection page if just one   39.988425
# 206    [CVS Repo View] Repository view should select ...   55.090892
# 7148   [CVS Repo View] Expanding project version node...   55.496353
# 57178  [Repo View] Allow to paste CVS connection stri...   59.812003
# 4370   Validate repo connection option should be on b...   53.015697
# 6207   [CVS UI] Replace With -> Latest From Repositor...   57.700217
# 2581   [CVS Repo View UI] CVS and deleted/restored files   65.842009
# 10521     [CVS UI] default setting for empty directories   61.828357
# 34827  [Repo View] Popup menu does not appears in CVS...   56.489789
#
#        SimilarityDescription  AvgSimilarity
# 24                100.000012     100.000006
# 11516              55.385458      59.547460
# 4055               56.444019      55.632553
# 25                 60.622609      54.914929
# 63677              56.381154      54.785883
# 10814              47.817951      54.715371
# 18279              56.400722      54.274279
# 4158               46.693420      53.583103
# 38                 62.870204      53.453931
# 13578              53.275734      53.441727
# 7138               47.678283      53.337355
# 3331               66.472083      53.230254
# 206                49.951500      52.521196
# 7148               49.359906      52.428129
# 57178              44.865108      52.338555
# 4370               51.650834      52.333266
# 6207               46.460965      52.080591
# 2581               38.201869      52.021939
# 10521              42.140990      51.984674
# 34827              47.321212      51.905501

# %%
tempData=tempData.sort_values(by='Similarity', ascending=False)
tempData.head(20)
# Out:
#        Issue_id Priority Component  \
# 24           25       P3      Team
# 6723      14002       P3      Team
# 2581       5782       P2      Team
# 14970     28651       P3      Team
# 18596     35509       P3      Team
# 11516     22171       P3      Team
# 12448     23878       P3      Team
# 21675     41942       P3      Team
# 5707      12079       P3      Team
# 12967     24843       P3      Team
# 22395     43509       P3      Team
# 12671     24281       P3      Team
# 10521     20463       P5      Team
# 10814     20955       P3      Team
# 12640     24216       P3      Team
# 18648     35613       P3      Team
# 13559     26021       P3      Team
# 18436     35200       P4      Team
# 6926      14374       P3      Team
# 4158       8891       P3      Team
#
#                                              Description  \
# 24     It would be helpful if there was a notion of d...
# 6723   This is using build 2002-04-12; ; When creatin...
# 2581   At some point in the past (before I used Eclip...
# 14970  Right now some of the CVS preferences are glob...
# 18596  In the CVS Location Properties dialog; we inhe...
# 11516  I havent found any way to create a new reposit...
# 12448  One of the issues we are expierencing with Ecl...
# 21675  If a repository that contains a large number o...
# 5707   It would be nifty to have a radio button when ...
# 12967  VCM is looping on all windows and pages to sav...
# 22395  Since it is now possible to specify read and w...
# 12671  Remove anonymous dev.eclipse.org connection fr...
# 10521  CVS default setting for empty directories; ins...
# 10814  Build 20020624; ; Would like to be able to nam...
# 12640  2.1 M1; ; When comparing 2 versions of a proje...
# 18648  Build : RC2;    ; 1. Firstly ; If I select n n...
# 13559  build I20021105; ; Its easy to get lost in the...
# 18436  Hello;; It seems that the Open menu item in th...
# 6926   http://dev.eclipse.org/bugs/show_bug.cgi?id=14372
# 4158   You cant change any of the properties of a CVS...
#
#                                                    Title  Similarity  \
# 24     [CVS UI] Need VCM Prefs - Default Repo Connect...  100.000000
# 6723   [CVS UI] Better flow when creating invalid rep...   66.502631
# 2581   [CVS Repo View UI] CVS and deleted/restored files   65.842009
# 14970  [Repo View] some cvs preferences should be per...   65.557420
# 18596  [CVS UI] Restore Defaults button in CVS Locati...   64.547443
# 11516  [CVS UI] New Repo Location wizard should be ac...   63.709462
# 12448  [CVS UI Repo View] Allow user to checkout a sp...   63.365906
# 21675  [CVS Repo View Concurrency] UI unreponsive whe...   63.083684
# 5707   [CVS UI] Anonymous as radio option for repo lo...   62.765241
# 12967  [CVS UI] VCM should use IWorkbench.saveAllEditors   62.693143
# 22395               [CVS UI] Hide locations in Repo View   62.450790
# 12671         [CVS UI] remove dev.eclipse.org connection   62.074077
# 10521     [CVS UI] default setting for empty directories   61.828357
# 10814   [CVS UI] Would like to name repository locations   61.612791
# 12640  [CVS UI] Want simpler way to quickly select mu...   61.360973
# 18648    [Repo View] CVS Repositories View: Collapse All   61.195189
# 13559  [CVS Repo View] Repo explorer should show path...   60.759151
# 18436  [CVS Repo View] Open menu in the CVS repositor...   60.701931
# 6926   [CVS UI] Tag dialog: Update from repository do...   60.502446
# 4158   Cant change properties of a CVS connection in ...   60.472786
#
#        SimilarityDescription  AvgSimilarity
# 24                100.000012     100.000006
# 6723               29.638180      48.070405
# 2581               38.201869      52.021939
# 14970              32.199597      48.878509
# 18596              38.325709      51.436576
# 11516              55.385458      59.547460
# 12448              28.025919      45.695913
# 21675              39.758614      51.421149
# 5707               33.362529      48.063885
# 12967              27.865815      45.279479
# 22395              39.378864      50.914827
# 12671              40.560746      51.317412
# 10521              42.140990      51.984674
# 10814              47.817951      54.715371
# 12640              30.443147      45.902060
# 18648              34.606797      47.900993
# 13559              27.171889      43.965520
# 18436              33.008236      46.855083
# 6926               -0.922893      29.789776
# 4158               46.693420      53.583103

# %%
tempData=tempData.sort_values(by='SimilarityDescription', ascending=False)
tempData.head(20)
# Out:
#        Issue_id Priority  Component  \
# 24           25       P3       Team
# 3331       7410       P3       Team
# 3332       7412       P3       Team
# 97           98       P3       Team
# 38           39       P3       Team
# 25           26       P5       Team
# 72225    266536       P3     Releng
# 3335       7415       P3       Team
# 42027     89672       P3  Resources
# 254         255       P5       Team
# 39675     83271       P3      Debug
# 3330       7409       P3       Team
# 19           20       P2       Team
# 17578     33643       P3         UI
# 4055       8712       P3       Team
# 18279     34915       P3       Team
# 63677    196475       P3        CVS
# 77495    319326       P3        SWT
# 5459      11597       P3         UI
# 11516     22171       P3       Team
#
#                                              Description  \
# 24     It would be helpful if there was a notion of d...
# 3331   When creating a new repo connection; if you on...
# 3332   When creating a new repository connection; it ...
# 97     We need a New button in the repo connection di...
# 38     I may have logged this previously.; ; It would...
# 25     Its very awkward that you cannot create a new ...
# 72225  Created attachment 127032; Patch to p2.inf fil...
# 3335   In the Connect to Team wizard; the Finish butt...
# 42027  Build I20050330-0500; ; The default value for ...
# 254    Perhaps this is the way that you want it to ha...
# 39675  When I have a class selected and I do run as i...
# 3330   If you create a new CVS conncetion in the Repo...
# 19     Thought it would be useful if the set of repo ...
# 17578  The New Java Project wizard should remember th...
# 4055   When sharing a project; its great that we now ...
# 18279  Many times; Ive made changes to files which I ...
# 63677  Build ID: I20070710-1416; ; I wonder if we cou...
# 77495  Build Identifier: I20100608-0911; ; When you t...
# 5459   It would be nice to have an option to prompt/w...
# 11516  I havent found any way to create a new reposit...
#
#                                                    Title  Similarity  \
# 24     [CVS UI] Need VCM Prefs - Default Repo Connect...  100.000000
# 3331    Should skip repo type selection page if just one   39.988425
# 3332   Repo Connnection Wizard: should be able to adv...   34.152153
# 97                                                  Need   -1.883249
# 38      Preference for repo type would be nice (1GCPKVS)   44.037658
# 25     Need to be able to create a new Repo Connectio...   49.207249
# 72225                          Specify update site names   12.452231
# 3335         Connection Wizard: Finish enabled too early   17.953421
# 42027  default value for refreshing workspace automat...   36.020476
# 254        Double prompt for release comments. (1GKCUF8)   16.290624
# 39675                          run as creates duplicates    9.929173
# 3330   New connections now showing CVS Repositories view   43.179530
# 19                                       Workspace files   11.083525
# 17578  [Wizards] Improvements to the New Java Project...   12.496414
# 4055   Share with CVS wizard: repo connection list di...   54.821086
# 18279  Load latest from repo option in sync view outg...   52.147835
# 63677  [Repo View] Ordering in the CVS Repositories view   53.190613
# 77495              Crash while connecting to repository.   34.455684
# 5459   [Preferences] Option to prompt user about unsa...   26.694304
# 11516  [CVS UI] New Repo Location wizard should be ac...   63.709462
#
#        SimilarityDescription  AvgSimilarity
# 24                100.000012     100.000006
# 3331               66.472083      53.230254
# 3332               64.619792      49.385972
# 97                 64.032352      31.074552
# 38                 62.870204      53.453931
# 25                 60.622609      54.914929
# 72225              60.518855      36.485543
# 3335               59.547901      38.750661
# 42027              59.153068      47.586772
# 254                58.023494      37.157059
# 39675              57.291210      33.610191
# 3330               57.136303      50.157917
# 19                 56.519592      33.801558
# 17578              56.515068      34.505741
# 4055               56.444019      55.632553
# 18279              56.400722      54.274279
# 63677              56.381154      54.785883
# 77495              55.900317      45.178001
# 5459               55.554575      41.124439
# 11516              55.385458      59.547460
